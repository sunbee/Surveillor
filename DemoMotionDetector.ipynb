# %%
from classifyable import *
from MotionDetector import MotionDetector

# %%
first = Classifyable()
first.set_snap()
first.show_snap()
second = Classifyable()
second.set_snap()
second.show_snap()

# %%
Sur = MotionDetector(first, second, showme=True)
base, compare, diff, level, clean, mask, res = Sur.sense()
res
# Out:
# {}

# %%
def make2takes():
    first = Classifyable()
    second = Classifyable()
    
    first.set_snap()
    second.set_snap()
    
    return first, second

# %%
f, s = make2takes()
Sur2 = MotionDetector(f, s, showme=True)
base2, compare2, diff2, level2, clean2, mask2, res2 = Sur2.sense()
res2
# Out:
# {3: 5002,
#  223: 3707,
#  565: 3492,
#  676: 2831,
#  566: 1314,
#  9: 1116,
#  1104: 704,
#  368: 476,
#  1175: 424,
#  1251: 248,
#  120: 185,
#  1087: 152,
#  182: 111,
#  499: 99,
#  769: 96}

# %%
f3, s3 = make2takes()
Sur3 = MotionDetector(f3, s3, showme=True)
base3, compare3, diff3, level3, clean3, mask3, res3 = Sur3.sense()
res3
# Out:
# {199: 2934,
#  184: 1385,
#  58: 744,
#  37: 545,
#  401: 373,
#  578: 368,
#  504: 336,
#  132: 298,
#  554: 173,
#  178: 149,
#  204: 104,
#  610: 94}
