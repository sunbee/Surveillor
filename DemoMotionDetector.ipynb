# %%
from MotionDetector import MotionDetector

# %%
Sur = MotionDetector(showme=True)
base, compare, diff, level, clean, mask, res = Sur.sense()
res
# Out:
# /usr/lib/python3/dist-packages/picamera/encoders.py:544: PiCameraResolutionRounded: frame size rounded up from 300x300 to 320x304
#   width, height, fwidth, fheight)))
# {}

# %%
Sur2 = MotionDetector(showme=True)
base2, compare2, diff2, level2, clean2, mask2, res2 = Sur.sense()
res2
# Out:
# /usr/lib/python3/dist-packages/picamera/encoders.py:544: PiCameraResolutionRounded: frame size rounded up from 300x300 to 320x304
#   width, height, fwidth, fheight)))
# {371: 429, 234: 217, 153: 174, 270: 142, 359: 131, 331: 113}

# %%
Sur3 = MotionDetector(showme=True)
base3, compare3, diff3, level3, clean3, mask3, res3 = Sur.sense()
res3
# Out:
# /usr/lib/python3/dist-packages/picamera/encoders.py:544: PiCameraResolutionRounded: frame size rounded up from 300x300 to 320x304
#   width, height, fwidth, fheight)))
# {1: 43227,
#  1510: 5176,
#  8: 2247,
#  1122: 1003,
#  1343: 696,
#  1582: 645,
#  631: 513,
#  1304: 398,
#  1497: 355,
#  9: 309,
#  1108: 281,
#  1589: 215,
#  1332: 117,
#  4: 114,
#  1258: 107}
